# %% [markdown]
# ![TheBridge_logo_RGB_color.jpg](attachment:TheBridge_logo_RGB_color.jpg)

# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# ## EJERCICIOS PYTHON BASICO 2:
# ## Tipos y conversión de tipos

# %% [markdown]
# Completa los siguiente ejercicios, la solución a los mismos se publicarán en el repo del curso a lo largo del sprint

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 1
#
# 1. Crea dos variables numericas: un `int` y un `float`
# 2. Comprueba sus tipos
# 3. Sumalas en otra nueva
# 4. ¿De qué tipo es la nueva variable?
# 5. Elimina las dos primeras variables creadas

# %%
entero = 5
real = 7.5
print(type(entero))
print(entero)
print(type(real))
print(real)
# Out:
# <class 'int'>
# 5
# <class 'float'>
# 7.5

# %%
suma_entero_real = entero + real
print(type(suma_entero_real))
print(suma_entero_real)
# Out:
# <class 'float'>
# 12.5

# %%
del entero
del real

# %%
print(entero)
print(real)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(entero)
#       2 print(real)
#
# NameError: name 'entero' is not defined

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 2
# Escribe un programa para pasar de grados a radianes. Hay que usar `input`. Recuerda que la conversión se realiza mediante
#
# radianes = grados*(pi/180)

# %%
grados = input("Cuantos grados quieres convertir?: ")
grados_numericos = float(grados)
pi = 3.14159265359
radianes = grados_numericos * (pi/180)
print(grados, "grados son", radianes, "radianes")
# Out:
# Cuantos grados quieres convertir?:  40
# 40 grados son 0.6981317007977778 radianes

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 3
# Escribe un programa que calcule el area de un paralelogramo (base x altura). También con `input`

# %%
base = input("Cuanto es la base del paralelogramo?: ")
altura = input("Cuanto es la altura del paralelogramo?: ")
base_numerica = float(base)
altura_numerica = float(altura)
area_paralelogramo = base_numerica * altura_numerica
print(base, "cm de base *", altura, "cm de altura =", area_paralelogramo, "cm cuadrados")
# Out:
# Cuanto es la base del paralelogramo?:  7.44
# Cuanto es la altura del paralelogramo?:  9.26
# 7.44 cm de base * 9.26 cm de altura = 68.8944 cm cuadrados

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 4
# Escribe un programa que calcule el area de un paralelogramo (base x altura). También con `input`. En este caso debe ser capaz de admitir valores reales, con decimales, para base y altura en español. (PISTA: Recuerda que tendrás que hacer uso del método replace)

# %%
base = input("Cuanto es la base del paralelogramo?: ")
altura = input("Cuanto es la altura del paralelogramo?: ")
base = base.replace(",", ".")
altura = altura.replace(",", ".")
base_numerica = float(base)
altura_numerica = float(altura)
area_paralelogramo = base_numerica * altura_numerica
print(base, "cm de base *", altura, "cm de altura =", area_paralelogramo, "cm cuadrados")
# Out:
# Cuanto es la base del paralelogramo?:  4,78
# Cuanto es la altura del paralelogramo?:  0.33
# 4.78 cm de base * 0.33 cm de altura = 1.5774000000000001 cm cuadrados

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 5
# Complete el siguiente código para solicitar al usuario su nombre y su edad. Luego, calcule en qué año nació el usuario y muestre el resultado.

# %%
nombre = input("¿Cuál es tu nombre?: ")
edad = input("¿Cuál es tu edad?: ")
edad_numerica = int(edad)
año_actual = 2025  # Puedes cambiarlo según el año en curso
año_nacimiento = año_actual - edad_numerica

print(f"{nombre}, naciste en el año {año_nacimiento}.")
# Out:
# ¿Cuál es tu nombre?:  Gian
# ¿Cuál es tu edad?:  30
# Gian, naciste en el año 1995.
